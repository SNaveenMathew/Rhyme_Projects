# %% [markdown]
# # TASK #1: PROJECT OVERVIEW

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES/DATASETS

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open("./traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("./traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("./traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']

# %%
X_validation, y_validation = valid['features'], valid['labels']

# %%
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# # TASK #3: PERFORM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 12

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 5
L_grid = 5

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 5 x 5 matrix into 25 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
# create evenly spaces variables 
for i in np.arange(0, W_grid * L_grid):
    # Select a random number
    idx = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow(X_train[idx])
    axes[i].set_title(y_train[idx], fontsize = 15)
    axes[i].axis('off')

plt.subplots_adjust(hspace = 0.4)

# %% [markdown]
# # TASK #4: CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train / 3, axis = 3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray - 128)/128

# %%
X_test_gray = np.sum(X_test / 3, axis = 3, keepdims = True)
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray = np.sum(X_validation / 3, axis = 3, keepdims = True)
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# # TASK #5: UNDERSTAND THE THEORY AND INTUITION BEHIND CONVOLUTIONAL NEURAL NETWORKS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #6: BUILD DEEP CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras import datasets, layers, models
CNN = models.Sequential()
CNN.add(layers.Conv2D(6, (5, 5), activation = 'relu', input_shape = (32, 32, 1)))
CNN.add(layers.AveragePooling2D())
CNN.add(layers.Dropout(0.2))
CNN.add(layers.Conv2D(16, (5, 5), activation = 'relu'))
CNN.add(layers.AveragePooling2D())
CNN.add(layers.Flatten())
CNN.add(layers.Dense(120, activation = 'relu'))
CNN.add(layers.Dense(84, activation = 'relu'))
CNN.add(layers.Dense(43, activation = 'softmax'))
CNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # TASK #7: COMPILE AND TRAIN DEEP CNN MODEL

# %%
CNN.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = CNN.fit(
    X_train_gray_norm,
    y_train,
    batch_size = 500,
    epochs = 50,
    verbose = 1,
    validation_data = (X_validation_gray_norm, y_validation)
)
# Out:
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/50
# 34799/34799 [==============================] - 33s 938us/sample - loss: 0.5658 - accuracy: 0.8384 - val_loss: 0.6471 - val_accuracy: 0.8073
# Epoch 2/50
# 34799/34799 [==============================] - 35s 1ms/sample - loss: 0.4845 - accuracy: 0.8613 - val_loss: 0.5625 - val_accuracy: 0.8374
# Epoch 3/50
# 34799/34799 [==============================] - 33s 961us/sample - loss: 0.4273 - accuracy: 0.8805 - val_loss: 0.5261 - val_accuracy: 0.8587
# Epoch 4/50
# 34799/34799 [==============================] - 33s 936us/sample - loss: 0.3750 - accuracy: 0.8926 - val_loss: 0.5042 - val_accuracy: 0.8605
# Epoch 5/50
# 34799/34799 [==============================] - 33s 962us/sample - loss: 0.3384 - accuracy: 0.9061 - val_loss: 0.4728 - val_accuracy: 0.8739
# Epoch 6/50
# 34799/34799 [==============================] - 32s 918us/sample - loss: 0.3072 - accuracy: 0.9142 - val_loss: 0.4755 - val_accuracy: 0.8746
# Epoch 7/50
# 34799/34799 [==============================] - 32s 913us/sample - loss: 0.2813 - accuracy: 0.9215 - val_loss: 0.4447 - val_accuracy: 0.8807
# Epoch 8/50
# 34799/34799 [==============================] - 31s 904us/sample - loss: 0.2538 - accuracy: 0.9297 - val_loss: 0.4582 - val_accuracy: 0.8773
# Epoch 9/50
# 34799/34799 [==============================] - 32s 918us/sample - loss: 0.2266 - accuracy: 0.9376 - val_loss: 0.4345 - val_accuracy: 0.8791
# Epoch 10/50
# 34799/34799 [==============================] - 31s 904us/sample - loss: 0.2185 - accuracy: 0.9406 - val_loss: 0.4676 - val_accuracy: 0.8832
# Epoch 11/50
# 34799/34799 [==============================] - 32s 914us/sample - loss: 0.1998 - accuracy: 0.9440 - val_loss: 0.4601 - val_accuracy: 0.8812
# Epoch 12/50
# 34799/34799 [==============================] - 31s 902us/sample - loss: 0.1902 - accuracy: 0.9470 - val_loss: 0.4442 - val_accuracy: 0.8812
# Epoch 13/50
# 34799/34799 [==============================] - 30s 873us/sample - loss: 0.1739 - accuracy: 0.9524 - val_loss: 0.4276 - val_accuracy: 0.8932
# Epoch 14/50
# 34799/34799 [==============================] - 32s 909us/sample - loss: 0.1609 - accuracy: 0.9553 - val_loss: 0.4676 - val_accuracy: 0.8839
# Epoch 15/50
# 34799/34799 [==============================] - 31s 896us/sample - loss: 0.1461 - accuracy: 0.9599 - val_loss: 0.4310 - val_accuracy: 0.8878
# Epoch 16/50
# 34799/34799 [==============================] - 31s 888us/sample - loss: 0.1399 - accuracy: 0.9615 - val_loss: 0.4407 - val_accuracy: 0.8855
# Epoch 17/50
# 34799/34799 [==============================] - 32s 934us/sample - loss: 0.1335 - accuracy: 0.9620 - val_loss: 0.4331 - val_accuracy: 0.8898
# Epoch 18/50
# 34799/34799 [==============================] - 33s 942us/sample - loss: 0.1246 - accuracy: 0.9650 - val_loss: 0.4416 - val_accuracy: 0.8984
# Epoch 19/50
# 34799/34799 [==============================] - 32s 910us/sample - loss: 0.1173 - accuracy: 0.9661 - val_loss: 0.4551 - val_accuracy: 0.8932
# Epoch 20/50
# 34799/34799 [==============================] - 32s 910us/sample - loss: 0.1114 - accuracy: 0.9690 - val_loss: 0.4231 - val_accuracy: 0.9014
# Epoch 21/50
# 34799/34799 [==============================] - 31s 889us/sample - loss: 0.1013 - accuracy: 0.9725 - val_loss: 0.5067 - val_accuracy: 0.8971
# Epoch 22/50
# 34799/34799 [==============================] - 32s 913us/sample - loss: 0.0977 - accuracy: 0.9722 - val_loss: 0.4898 - val_accuracy: 0.9025
# Epoch 23/50
# 34799/34799 [==============================] - 30s 858us/sample - loss: 0.0948 - accuracy: 0.9737 - val_loss: 0.4582 - val_accuracy: 0.8977
# Epoch 24/50
# 34799/34799 [==============================] - 31s 904us/sample - loss: 0.0890 - accuracy: 0.9744 - val_loss: 0.4759 - val_accuracy: 0.8966
# Epoch 25/50
# 34799/34799 [==============================] - 30s 849us/sample - loss: 0.0867 - accuracy: 0.9732 - val_loss: 0.4907 - val_accuracy: 0.8950
# Epoch 26/50
# 34799/34799 [==============================] - 30s 854us/sample - loss: 0.0838 - accuracy: 0.9752 - val_loss: 0.5062 - val_accuracy: 0.8914
# Epoch 27/50
# 34799/34799 [==============================] - 38s 1ms/sample - loss: 0.0756 - accuracy: 0.9782 - val_loss: 0.5030 - val_accuracy: 0.8991
# Epoch 28/50
# 34799/34799 [==============================] - 31s 878us/sample - loss: 0.0707 - accuracy: 0.9801 - val_loss: 0.5181 - val_accuracy: 0.8993
# Epoch 29/50
# 34799/34799 [==============================] - 32s 921us/sample - loss: 0.0685 - accuracy: 0.9805 - val_loss: 0.4662 - val_accuracy: 0.9063
# Epoch 30/50
# 34799/34799 [==============================] - 31s 885us/sample - loss: 0.0638 - accuracy: 0.9812 - val_loss: 0.4477 - val_accuracy: 0.9098
# Epoch 31/50
# 34799/34799 [==============================] - 31s 899us/sample - loss: 0.0652 - accuracy: 0.9818 - val_loss: 0.5218 - val_accuracy: 0.8959
# Epoch 32/50
# 34799/34799 [==============================] - 33s 953us/sample - loss: 0.0631 - accuracy: 0.9816 - val_loss: 0.5046 - val_accuracy: 0.8980
# Epoch 33/50
# 34799/34799 [==============================] - 32s 925us/sample - loss: 0.0614 - accuracy: 0.9819 - val_loss: 0.5095 - val_accuracy: 0.9020
# Epoch 34/50
# 34799/34799 [==============================] - 32s 913us/sample - loss: 0.0536 - accuracy: 0.9844 - val_loss: 0.4708 - val_accuracy: 0.9036
# Epoch 35/50
# 34799/34799 [==============================] - 30s 872us/sample - loss: 0.0544 - accuracy: 0.9837 - val_loss: 0.4908 - val_accuracy: 0.9034
# Epoch 36/50
# 34799/34799 [==============================] - 33s 953us/sample - loss: 0.0530 - accuracy: 0.9849 - val_loss: 0.4695 - val_accuracy: 0.9095
# Epoch 37/50
# 34799/34799 [==============================] - 30s 866us/sample - loss: 0.0536 - accuracy: 0.9832 - val_loss: 0.5229 - val_accuracy: 0.9082
# Epoch 38/50
# 34799/34799 [==============================] - 32s 931us/sample - loss: 0.0466 - accuracy: 0.9865 - val_loss: 0.5200 - val_accuracy: 0.9050
# Epoch 39/50
# 34799/34799 [==============================] - 30s 874us/sample - loss: 0.0472 - accuracy: 0.9861 - val_loss: 0.5564 - val_accuracy: 0.9134
# Epoch 40/50
# 34799/34799 [==============================] - 31s 882us/sample - loss: 0.0435 - accuracy: 0.9875 - val_loss: 0.5074 - val_accuracy: 0.9005
# Epoch 41/50
# 34799/34799 [==============================] - 31s 889us/sample - loss: 0.0462 - accuracy: 0.9863 - val_loss: 0.5012 - val_accuracy: 0.9007
# Epoch 42/50
# 34799/34799 [==============================] - 31s 900us/sample - loss: 0.0434 - accuracy: 0.9867 - val_loss: 0.5379 - val_accuracy: 0.9025
# Epoch 43/50
# 34799/34799 [==============================] - 31s 893us/sample - loss: 0.0418 - accuracy: 0.9876 - val_loss: 0.5304 - val_accuracy: 0.9073
# Epoch 44/50
# 34799/34799 [==============================] - 32s 912us/sample - loss: 0.0419 - accuracy: 0.9878 - val_loss: 0.4986 - val_accuracy: 0.9098
# Epoch 45/50
# 34799/34799 [==============================] - 32s 931us/sample - loss: 0.0366 - accuracy: 0.9889 - val_loss: 0.5363 - val_accuracy: 0.9036
# Epoch 46/50
# 34799/34799 [==============================] - 32s 932us/sample - loss: 0.0379 - accuracy: 0.9884 - val_loss: 0.6076 - val_accuracy: 0.9027
# Epoch 47/50
# 34799/34799 [==============================] - 31s 889us/sample - loss: 0.0351 - accuracy: 0.9893 - val_loss: 0.4724 - val_accuracy: 0.9098
# Epoch 48/50
# 34799/34799 [==============================] - 30s 873us/sample - loss: 0.0341 - accuracy: 0.9898 - val_loss: 0.4901 - val_accuracy: 0.9088
# Epoch 49/50
# 34799/34799 [==============================] - 32s 920us/sample - loss: 0.0308 - accuracy: 0.9911 - val_loss: 0.4969 - val_accuracy: 0.9107
# Epoch 50/50
# 34799/34799 [==============================] - 30s 862us/sample - loss: 0.0349 - accuracy: 0.9899 - val_loss: 0.5301 - val_accuracy: 0.9061

# %% [markdown]
# # TASK #8: ASSESS TRAINED CNN MODEL PERFORMANCE

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
score = CNN.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 12630/12630 [==============================] - 7s 592us/sample - loss: 0.7671 - accuracy: 0.9008
# Test Accuracy: 0.9007917642593384

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))
plt.plot(epochs, loss, 'ro', label = 'Training loss')
plt.plot(epochs, val_loss, 'r', label = 'Validation loss')
plt.title('Training and Validation loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation loss')

# %%
plt.plot(epochs, accuracy, 'ro', label = 'Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label = 'Validation accuracy')
plt.title('Training and Validation accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation accuracy')

# %%
predicted_classes = CNN.predict_classes(X_test_gray_norm)
y_true = y_test

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)

# %% [markdown]
# # CONGRATULATIONS ON FINISHING THE PROJECT!

# %% [markdown]
# # APPENDIX

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons
#
# - Citation
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
# @inproceedings{Stallkamp-IJCNN-2011, author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel}, booktitle = {IEEE International Joint Conference on Neural Networks}, title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition}, year = {2011}, pages = {1453--1460} }
